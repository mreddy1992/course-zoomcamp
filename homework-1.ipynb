# %%
import numpy as np
import pandas as pd

# %%
print(np.__version__)
# Out:
# 1.21.5

# %%
df = pd.read_csv('chapter-02-car-price.csv')

# %%
print(f"How many records are in the dataset? {df.shape[0]}")
# Out:
# How many records are in the dataset? 11914

# %%
df['Make'].value_counts()[:3]
# Out:
# Chevrolet     1123
# Ford           881
# Volkswagen     809
# Name: Make, dtype: int64

# %%
list(df['Make'].value_counts()[:3].index.values)
# Out:
# ['Chevrolet', 'Ford', 'Volkswagen']

# %%
print(f"Who are the most frequent car manufacturers (top-3) according to the dataset? {list(df['Make'].value_counts()[:3].index.values)}")
# Out:
# Who are the most frequent car manufacturers (top-3) according to the dataset? ['Chevrolet', 'Ford', 'Volkswagen']

# %%
df_audi = df.loc[df['Make'] == 'Audi', ]

# %%
df_audi['Model'].nunique()
# Out:
# 34

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
df['Engine Cylinders'].median()
# Out:
# 6.0

# %%
mode_value = df['Engine Cylinders'].mode().values[0]
mode_value
# Out:
# 4.0

# %%
df['Engine Cylinders'] = df['Engine Cylinders'].fillna(mode_value)

# %%
df['Engine Cylinders'].isnull().sum()
# Out:
# 0

# %%
df['Engine Cylinders'].median()
# Out:
# 6.0

# %%
df_lotus = df.loc[df['Make'] == 'Lotus', ]
df_lotus
# Out:
#        Make      Model  Year                Engine Fuel Type  Engine HP  \
# 3912  Lotus      Elise  2009     premium unleaded (required)      189.0
# 3913  Lotus      Elise  2009     premium unleaded (required)      218.0
# 3914  Lotus      Elise  2009     premium unleaded (required)      189.0
# 3915  Lotus      Elise  2010     premium unleaded (required)      189.0
# 3916  Lotus      Elise  2010     premium unleaded (required)      218.0
# 3917  Lotus      Elise  2011     premium unleaded (required)      189.0
# 3918  Lotus      Elise  2011     premium unleaded (required)      217.0
# 3919  Lotus      Elise  2011     premium unleaded (required)      217.0
# 4216  Lotus     Esprit  2002     premium unleaded (required)      350.0
# 4217  Lotus     Esprit  2003     premium unleaded (required)      350.0
# 4218  Lotus     Esprit  2004     premium unleaded (required)      350.0
# 4257  Lotus  Evora 400  2017     premium unleaded (required)      400.0
# ...

# %%
df_lotus = df_lotus[['Engine HP', 'Engine Cylinders']]
df_lotus
# Out:
#       Engine HP  Engine Cylinders
# 3912      189.0               4.0
# 3913      218.0               4.0
# 3914      189.0               4.0
# 3915      189.0               4.0
# 3916      218.0               4.0
# 3917      189.0               4.0
# 3918      217.0               4.0
# 3919      217.0               4.0
# 4216      350.0               8.0
# 4217      350.0               8.0
# 4218      350.0               8.0
# 4257      400.0               6.0
# 4258      400.0               6.0
# 4259      276.0               6.0
# 4260      276.0               6.0
# 4261      276.0               6.0
# 4262      345.0               6.0
# 4263      345.0               6.0
# 4264      276.0               6.0
# 4265      345.0               6.0
# 4266      276.0               6.0
# 4267      345.0               6.0
# 4268      276.0               6.0
# 4292      257.0               4.0
# 4293      240.0               4.0
# 4294      240.0               4.0
# ...

# %%
df_lotus = df_lotus.drop_duplicates()
df_lotus
# Out:
#       Engine HP  Engine Cylinders
# 3912      189.0               4.0
# 3913      218.0               4.0
# 3918      217.0               4.0
# 4216      350.0               8.0
# 4257      400.0               6.0
# 4259      276.0               6.0
# 4262      345.0               6.0
# 4292      257.0               4.0
# 4293      240.0               4.0

# %%
df_lotus.shape[0] == 9
# Out:
# True

# %%
X = np.array(df_lotus)
X
# Out:
# array([[189.,   4.],
#        [218.,   4.],
#        [217.,   4.],
#        [350.,   8.],
#        [400.,   6.],
#        [276.,   6.],
#        [345.,   6.],
#        [257.,   4.],
#        [240.,   4.]])

# %%
XTX = X.T.dot(X)
XTX
# Out:
# array([[7.31684e+05, 1.34100e+04],
#        [1.34100e+04, 2.52000e+02]])

# %%
y = [1100, 800, 750, 850, 1300, 1000, 1000, 1300, 800]
y
# Out:
# [1100, 800, 750, 850, 1300, 1000, 1000, 1300, 800]

# %%
w = np.linalg.inv(XTX).dot(X.T).dot(y)

# %%
w[0]
# Out:
# 4.594944810094579
